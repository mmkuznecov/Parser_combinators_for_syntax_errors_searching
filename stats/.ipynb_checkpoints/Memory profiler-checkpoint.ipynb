# %%
import seaborn as sn
import matplotlib.pyplot as plt

# %%
def read_dat(path):
    with open(path, 'r') as f:
        data = f.readlines()
    data.remove(data[0])
    mems = [float(data[i].split()[1]) for i in range(len(data))]
    return mems

# %%
data = read_dat('mprofile_20201022172436.dat')
times = [0.1 * i for i in range(len(data))]
data, times
# Out:
# ([0.972656,
#   12.320312,
#   15.078125,
#   15.078125,
#   15.078125,
#   13.527344,
#   18.457031,
#   18.457031,
#   18.707031,
#   18.707031,
#   18.957031,
#   18.957031,
#   19.207031,
#   19.207031,
#   19.457031,
#   19.457031,
#   19.457031,
#   19.707031,
#   19.707031,
#   19.707031,
#   19.957031,
#   19.957031,
#   20.207031,
#   20.207031,
#   20.457031,
#   20.457031,
#   20.707031,
#   20.707031,
#   20.957031,
#   20.957031,
#   21.207031,
#   21.207031,
#   21.457031,
#   21.707031,
#   21.707031,
#   21.957031,
#   21.957031,
#   22.207031,
#   22.207031,
#   22.457031,
#   22.457031,
#   22.707031,
#   22.707031,
#   22.957031,
#   22.957031,
#   23.207031,
#   23.207031,
#   23.457031,
#   23.746094,
#   23.746094,
#   24.027344,
#   24.027344,
#   24.304688,
#   24.304688,
#   24.585938,
#   18.605469,
#   18.605469,
#   18.605469,
#   18.855469,
#   19.105469,
#   19.105469,
#   19.355469,
#   19.355469,
#   19.605469,
#   19.605469,
#   19.855469,
#   19.855469,
#   20.105469,
#   20.105469,
#   20.355469,
#   20.355469,
#   20.605469,
#   20.605469,
#   20.855469,
#   21.105469,
#   21.105469,
#   21.355469,
#   21.355469,
#   21.605469,
#   21.605469,
#   21.855469,
#   21.855469,
#   22.105469,
#   22.105469,
#   22.355469,
#   22.355469,
#   22.605469,
#   22.855469,
#   22.855469,
#   23.105469,
#   23.105469,
#   23.355469,
#   23.355469,
#   23.605469,
#   23.605469,
#   23.855469,
#   23.855469,
#   24.105469,
#   24.105469,
#   24.355469,
#   24.355469,
#   24.605469,
#   24.605469],
#  [0.0,
#   0.1,
#   0.2,
#   0.30000000000000004,
#   0.4,
#   0.5,
#   0.6000000000000001,
#   0.7000000000000001,
#   0.8,
#   0.9,
#   1.0,
#   1.1,
#   1.2000000000000002,
#   1.3,
#   1.4000000000000001,
#   1.5,
#   1.6,
#   1.7000000000000002,
#   1.8,
#   1.9000000000000001,
#   2.0,
#   2.1,
#   2.2,
#   2.3000000000000003,
#   2.4000000000000004,
#   2.5,
#   2.6,
#   2.7,
#   2.8000000000000003,
#   2.9000000000000004,
#   3.0,
#   3.1,
#   3.2,
#   3.3000000000000003,
#   3.4000000000000004,
#   3.5,
#   3.6,
#   3.7,
#   3.8000000000000003,
#   3.9000000000000004,
#   4.0,
#   4.1000000000000005,
#   4.2,
#   4.3,
#   4.4,
#   4.5,
#   4.6000000000000005,
#   4.7,
#   4.800000000000001,
#   4.9,
#   5.0,
#   5.1000000000000005,
#   5.2,
#   5.300000000000001,
#   5.4,
#   5.5,
#   5.6000000000000005,
#   5.7,
#   5.800000000000001,
#   5.9,
#   6.0,
#   6.1000000000000005,
#   6.2,
#   6.300000000000001,
#   6.4,
#   6.5,
#   6.6000000000000005,
#   6.7,
#   6.800000000000001,
#   6.9,
#   7.0,
#   7.1000000000000005,
#   7.2,
#   7.300000000000001,
#   7.4,
#   7.5,
#   7.6000000000000005,
#   7.7,
#   7.800000000000001,
#   7.9,
#   8.0,
#   8.1,
#   8.200000000000001,
#   8.3,
#   8.4,
#   8.5,
#   8.6,
#   8.700000000000001,
#   8.8,
#   8.9,
#   9.0,
#   9.1,
#   9.200000000000001,
#   9.3,
#   9.4,
#   9.5,
#   9.600000000000001,
#   9.700000000000001,
#   9.8,
#   9.9,
#   10.0,
#   10.100000000000001,
#   10.200000000000001])

# %%
sn.set_style('whitegrid')
plt.plot(times, data)
plt.xlabel('Time, seconds')
plt.ylabel('Memory used, MiB')
plt.show()
