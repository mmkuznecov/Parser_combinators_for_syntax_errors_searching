# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'r', [1, 2, 3, 4], [1, 8, 27, 64], 'g' ,[1, 2, 3, 4], [1, 2, 3, 4], 'b')
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'r', label = "CS")
plt.xlabel('Number of iteration')
plt.ylabel('Time per iteration')
plt.suptitle('Some plot')
stdev = 1
mean = 1
textstr = '\n'.join((
    r'$\mathrm{stdev}=%.2f$' % (stdev, ),
    r'$\mathrm{mean}=%.2f$' % (mean, )))
plt.text(4.5,13,textstr, fontsize=10)
plt.text(4.5,6,textstr,  fontsize=10)
plt.rcParams['figure.figsize'] = (15,15)
plt.grid()
plt.legend()
#plt.show()
plt.savefig('plot.png')

# %%
import datetime
import time
a = datetime.datetime.now()
time.sleep(1)
b = datetime.datetime.now()
(b - a).microseconds
# Out:
# 931

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)

fig, ax = plt.subplots()
x = 30*np.random.randn(10000)
mu = x.mean()
median = np.median(x)
sigma = x.std()
textstr = '\n'.join((
    r'$\mu=%.2f$' % (mu, ),
    r'$\mathrm{median}=%.2f$' % (median, ),
    r'$\sigma=%.2f$' % (sigma, )))

ax.hist(x, 50)
# these are matplotlib.patch.Patch properties
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)

# place a text box in upper left in axes coords
ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

plt.show()

# %%
from datetime import datetime
import time
t1 = datetime.now()
time.sleep(80)
t2 = datetime.now()

# %%
(t2-t1).seconds
# Out:
# 80

# %%
t4-t3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-36f0f465be59> in <module>
# ----> 1 t4-t3
#
# NameError: name 't4' is not defined

# %%
import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2020, 10, 18, 19, 43, 58, 899763)

# %%
import time
int(time.time())
# Out:
# 1603039743

# %%
import pandas as pd

# %%
list1 = [1,2,3,4,5]
list2 = [6,7,8,9,10]

data = {"1l" : list1, "2l" : list2}

df = pd.DataFrame(data)  
    
# saving the dataframe  
df.to_csv('GFG.csv')

# %%
df_ = pd.read_csv('GFG.csv')
df_.head()
# Out:
#    Unnamed: 0  1l  2l
# 0           0   1   6
# 1           1   2   7
# 2           2   3   8
# 3           3   4   9
# 4           4   5  10
